# %% [markdown]
# # Overview
# 1. Add CVE Descriptions to Top 25 removing newlines, tabs,... and escaping as required
# 2. Remove entries where CWE is not a CWE e.g. NVD-CWE-Insufficient-Info, UNSURE

# %%
import pandas as pd
import csv
import re

# %%
df_cve = pd.read_csv('./data_out/CVSSData.csv.gz', quoting=csv.QUOTE_ALL, escapechar='\\', compression='gzip')
df_cve
# Out:
#                   CVE   Published  \
# 0       CVE-1999-0095  1988-10-01
# 1       CVE-1999-0082  1988-11-11
# 2       CVE-1999-1471  1989-01-01
# 3       CVE-1999-1122  1989-07-26
# 4       CVE-1999-1467  1989-10-26
# ...               ...         ...
# 248446  CVE-2024-8039  2024-09-14
# 248447  CVE-2024-8724  2024-09-14
# 248448  CVE-2024-8479  2024-09-14
# 248449  CVE-2024-8246  2024-09-14
# 248450  CVE-2024-8797  2024-09-14
#
#                                               Description AttackVector CVSS3  \
# 0       The debug command in Sendmail is enabled, allo...       Missing_Data
# 1           CWD ~root command in ftpd allows root access.       Missing_Data
# 2       Buffer overflow in passwd in BSD based operati...       Missing_Data
# 3       Vulnerability in restore in SunOS 4.0.3 and ea...       Missing_Data
# 4       Vulnerability in rcp on SunOS 4.0.x allows rem...       Missing_Data
# ...                                                   ...                ...
# 248446  Improper permission configurationDomain config...       Missing_Data
# 248447  The Waitlist Woocommerce ( Back in stock notif...            NETWORK
# 248448  The The Simple Spoiler plugin for WordPress is...            NETWORK
# 248449  The Post Form – Registration Form – Profile Fo...            NETWORK
# 248450  The WP Booking System – Booking Calendar plugi...            NETWORK
#
#        AttackComplexity CVSS3 PrivilegesRequired CVSS3 UserInteraction CVSS3  \
# 0                Missing_Data             Missing_Data          Missing_Data
# 1                Missing_Data             Missing_Data          Missing_Data
# 2                Missing_Data             Missing_Data          Missing_Data
# 3                Missing_Data             Missing_Data          Missing_Data
# 4                Missing_Data             Missing_Data          Missing_Data
# ...                       ...                      ...                   ...
# 248446           Missing_Data             Missing_Data          Missing_Data
# 248447                    LOW                     NONE              REQUIRED
# 248448                    LOW                     NONE                  NONE
# 248449                    LOW                      LOW                  NONE
# 248450                    LOW                     NONE              REQUIRED
#
#          Scope CVSS3 ConfidentialityImpact CVSS3 IntegrityImpact CVSS3  ...  \
# 0       Missing_Data                Missing_Data          Missing_Data  ...
# 1       Missing_Data                Missing_Data          Missing_Data  ...
# 2       Missing_Data                Missing_Data          Missing_Data  ...
# 3       Missing_Data                Missing_Data          Missing_Data  ...
# 4       Missing_Data                Missing_Data          Missing_Data  ...
# ...              ...                         ...                   ...  ...
# 248446  Missing_Data                Missing_Data          Missing_Data  ...
# 248447       CHANGED                         LOW                   LOW  ...
# 248448     UNCHANGED                         LOW                   LOW  ...
# 248449     UNCHANGED                        HIGH                  HIGH  ...
# 248450       CHANGED                         LOW                   LOW  ...
#
#        AccessComplexity CVSS2  Authentication CVSS2  \
# 0                         LOW                  NONE
# 1                         LOW                  NONE
# 2                         LOW                  NONE
# 3                         LOW                  NONE
# 4                         LOW                  NONE
# ...                       ...                   ...
# 248446           Missing_Data          Missing_Data
# 248447           Missing_Data          Missing_Data
# 248448           Missing_Data          Missing_Data
# 248449           Missing_Data          Missing_Data
# 248450           Missing_Data          Missing_Data
#
#        ConfidentialityImpact CVSS2  IntegrityImpact CVSS2  \
# 0                         COMPLETE               COMPLETE
# 1                         COMPLETE               COMPLETE
# 2                         COMPLETE               COMPLETE
# 3                          PARTIAL                PARTIAL
# 4                         COMPLETE               COMPLETE
# ...                            ...                    ...
# 248446                Missing_Data           Missing_Data
# 248447                Missing_Data           Missing_Data
# 248448                Missing_Data           Missing_Data
# 248449                Missing_Data           Missing_Data
# 248450                Missing_Data           Missing_Data
#
#         AvailabilityImpact CVSS2 BaseScore CVSS2 BaseSeverity CVSS2  \
# 0                       COMPLETE            10.0       Missing_Data
# 1                       COMPLETE            10.0       Missing_Data
# 2                       COMPLETE             7.2       Missing_Data
# 3                        PARTIAL             4.6       Missing_Data
# 4                       COMPLETE            10.0       Missing_Data
# ...                          ...             ...                ...
# 248446              Missing_Data             0.0       Missing_Data
# 248447              Missing_Data             0.0       Missing_Data
# 248448              Missing_Data             0.0       Missing_Data
# 248449              Missing_Data             0.0       Missing_Data
# 248450              Missing_Data             0.0       Missing_Data
#
#        ExploitabilityScore CVSS2 ImpactScore CVSS2               CWEs
# 0                           10.0              10.0  ['NVD-CWE-Other']
# 1                           10.0              10.0  ['NVD-CWE-Other']
# 2                            3.9              10.0  ['NVD-CWE-Other']
# 3                            3.9               6.4  ['NVD-CWE-Other']
# 4                           10.0              10.0  ['NVD-CWE-Other']
# ...                          ...               ...                ...
# 248446                       0.0               0.0                 []
# 248447                       0.0               0.0         ['CWE-79']
# 248448                       0.0               0.0         ['CWE-94']
# 248449                       0.0               0.0        ['CWE-269']
# 248450                       0.0               0.0         ['CWE-79']
#
# [248451 rows x 26 columns]

# %% [markdown]
# ## Add CVE Description to CWE Observed and Top25 so they have the same format
# "CVE","Description","Chains","Weakness_Description"

# %%
df_observed = pd.read_csv('data_out/observed_examples.csv')

df_observed
# Out:
#         CWE-ID          CVE-ID  \
# 0     CWE-1004  CVE-2022-24045
# 1     CWE-1004   CVE-2014-3852
# 2     CWE-1004   CVE-2015-4138
# 3     CWE-1007   CVE-2013-7236
# 4     CWE-1007   CVE-2012-0584
# ...        ...             ...
# 2977    CWE-98   CVE-2004-0127
# 2978    CWE-98   CVE-2005-1971
# 2979    CWE-98   CVE-2005-3335
# 2980    CWE-98   CVE-2009-1936
# 2981    CWE-99   CVE-2013-4787
#
#                                             Description
# 0     Web application for a room automation system h...
# 1     CMS written in Python does not include the HTT...
# 2     Appliance for managing encrypted communication...
# 3     web forum allows impersonation of users with h...
# 4     Improper character restriction in URLs in web ...
# ...                                                 ...
# 2977  Directory traversal vulnerability in PHP inclu...
# 2978  Directory traversal vulnerability in PHP inclu...
# 2979  PHP file inclusion issue, both remote and loca...
# 2980  chain: library file sends a redirect if it is ...
# 2981  chain: mobile OS verifies cryptographic signat...
#
# [2982 rows x 3 columns]

# %%
df_observed.rename(columns={'CWE-ID': 'CWE', 'CVE-ID': 'CVE', 'Description': 'Weakness_Description'}, inplace=True)
df_observed
# Out:
#            CWE             CVE  \
# 0     CWE-1004  CVE-2022-24045
# 1     CWE-1004   CVE-2014-3852
# 2     CWE-1004   CVE-2015-4138
# 3     CWE-1007   CVE-2013-7236
# 4     CWE-1007   CVE-2012-0584
# ...        ...             ...
# 2977    CWE-98   CVE-2004-0127
# 2978    CWE-98   CVE-2005-1971
# 2979    CWE-98   CVE-2005-3335
# 2980    CWE-98   CVE-2009-1936
# 2981    CWE-99   CVE-2013-4787
#
#                                    Weakness_Description
# 0     Web application for a room automation system h...
# 1     CMS written in Python does not include the HTT...
# 2     Appliance for managing encrypted communication...
# 3     web forum allows impersonation of users with h...
# 4     Improper character restriction in URLs in web ...
# ...                                                 ...
# 2977  Directory traversal vulnerability in PHP inclu...
# 2978  Directory traversal vulnerability in PHP inclu...
# 2979  PHP file inclusion issue, both remote and loca...
# 2980  chain: library file sends a redirect if it is ...
# 2981  chain: mobile OS verifies cryptographic signat...
#
# [2982 rows x 3 columns]

# %%
df_observed = df_observed.merge(df_cve[['CVE', 'Description']], on='CVE', how='left')
df_observed
# Out:
#            CWE             CVE  \
# 0     CWE-1004  CVE-2022-24045
# 1     CWE-1004   CVE-2014-3852
# 2     CWE-1004   CVE-2015-4138
# 3     CWE-1007   CVE-2013-7236
# 4     CWE-1007   CVE-2012-0584
# ...        ...             ...
# 2977    CWE-98   CVE-2004-0127
# 2978    CWE-98   CVE-2005-1971
# 2979    CWE-98   CVE-2005-3335
# 2980    CWE-98   CVE-2009-1936
# 2981    CWE-99   CVE-2013-4787
#
#                                    Weakness_Description  \
# 0     Web application for a room automation system h...
# 1     CMS written in Python does not include the HTT...
# 2     Appliance for managing encrypted communication...
# 3     web forum allows impersonation of users with h...
# 4     Improper character restriction in URLs in web ...
# ...                                                 ...
# 2977  Directory traversal vulnerability in PHP inclu...
# 2978  Directory traversal vulnerability in PHP inclu...
# 2979  PHP file inclusion issue, both remote and loca...
# 2980  chain: library file sends a redirect if it is ...
# 2981  chain: mobile OS verifies cryptographic signat...
#
#                                             Description
# 0     A vulnerability has been identified in Desigo ...
# 1     Pyplate 0.08 does not include the HTTPOnly fla...
# 2     The WebUI component in Blue Coat SSL Visibilit...
# 3     Simple Machines Forum (SMF) 2.0.6, 1.1.19, and...
# 4     The Internationalized Domain Name (IDN) featur...
# ...                                                 ...
# 2977  Directory traversal vulnerability in editconfi...
# 2978  Directory traversal vulnerability in Interacti...
# 2979  PHP file inclusion vulnerability in bug_sponso...
# 2980  _functions.php in cpCommerce 1.2.x, possibly i...
# 2981  Android 1.6 Donut through 4.2 Jelly Bean does ...
#
# [2982 rows x 4 columns]

# %%
# Reorder columns
df_observed = df_observed[['CVE', 'CWE', 'Description', 'Weakness_Description']]
df_observed
# Out:
#                  CVE       CWE  \
# 0     CVE-2022-24045  CWE-1004
# 1      CVE-2014-3852  CWE-1004
# 2      CVE-2015-4138  CWE-1004
# 3      CVE-2013-7236  CWE-1007
# 4      CVE-2012-0584  CWE-1007
# ...              ...       ...
# 2977   CVE-2004-0127    CWE-98
# 2978   CVE-2005-1971    CWE-98
# 2979   CVE-2005-3335    CWE-98
# 2980   CVE-2009-1936    CWE-98
# 2981   CVE-2013-4787    CWE-99
#
#                                             Description  \
# 0     A vulnerability has been identified in Desigo ...
# 1     Pyplate 0.08 does not include the HTTPOnly fla...
# 2     The WebUI component in Blue Coat SSL Visibilit...
# 3     Simple Machines Forum (SMF) 2.0.6, 1.1.19, and...
# 4     The Internationalized Domain Name (IDN) featur...
# ...                                                 ...
# 2977  Directory traversal vulnerability in editconfi...
# 2978  Directory traversal vulnerability in Interacti...
# 2979  PHP file inclusion vulnerability in bug_sponso...
# 2980  _functions.php in cpCommerce 1.2.x, possibly i...
# 2981  Android 1.6 Donut through 4.2 Jelly Bean does ...
#
#                                    Weakness_Description
# 0     Web application for a room automation system h...
# 1     CMS written in Python does not include the HTT...
# 2     Appliance for managing encrypted communication...
# 3     web forum allows impersonation of users with h...
# 4     Improper character restriction in URLs in web ...
# ...                                                 ...
# 2977  Directory traversal vulnerability in PHP inclu...
# 2978  Directory traversal vulnerability in PHP inclu...
# 2979  PHP file inclusion issue, both remote and loca...
# 2980  chain: library file sends a redirect if it is ...
# 2981  chain: mobile OS verifies cryptographic signat...
#
# [2982 rows x 4 columns]

# %%
df_observed.to_csv("./data_out/observed_with_cve_descriptions.csv", index=False, quoting=csv.QUOTE_ALL, escapechar='\\')

# %% [markdown]
# ## Top25

# %%
df = pd.read_csv('./data_in/top25-mitre-mapping-analysis-2023-public.csv')

df
# Out:
#                  CVE  New CWE  \
# 0      CVE-2021-0674   CWE-20
# 1      CVE-2021-0674  CWE-125
# 2      CVE-2021-0676   CWE-20
# 3      CVE-2021-0676  CWE-125
# 4      CVE-2021-0677  CWE-190
# ...              ...      ...
# 9707  CVE-2022-29897   CWE-20
# 9708  CVE-2022-29922   CWE-20
# 9709   CVE-2022-3001   CWE-20
# 9710  CVE-2022-30232   CWE-20
# 9711  CVE-2022-30233   CWE-20
#
#                                               Reasoning
# 0     (Chains: CWE-20->CWE-125) Desc: "out of bounds...
# 1     (Chains: CWE-20->CWE-125) Desc: "out of bounds...
# 2     (Chains: CWE-20->CWE-125) Desc: "out of bounds...
# 3     (Chains: CWE-20->CWE-125) Desc: "out of bounds...
# 4     (Chains: CWE-190->CWE-125) Desc: "out of bound...
# ...                                                 ...
# 9707  "due to an improper input validation". ref men...
# 9708  "Improper Input Validation" in desc. NVD vendo...
# 9709  "improper input handling" and NVD Reference ma...
# 9710  desc: "CWE-20: Improper Input Validation" and ...
# 9711  desc: "CWE-20: Improper Input Validation" and ...
#
# [9712 rows x 3 columns]

# %%
df = df.merge(df_cve[['CVE', 'Description']], on='CVE', how='left')
df
# Out:
#                  CVE  New CWE  \
# 0      CVE-2021-0674   CWE-20
# 1      CVE-2021-0674  CWE-125
# 2      CVE-2021-0676   CWE-20
# 3      CVE-2021-0676  CWE-125
# 4      CVE-2021-0677  CWE-190
# ...              ...      ...
# 9707  CVE-2022-29897   CWE-20
# 9708  CVE-2022-29922   CWE-20
# 9709   CVE-2022-3001   CWE-20
# 9710  CVE-2022-30232   CWE-20
# 9711  CVE-2022-30233   CWE-20
#
#                                               Reasoning  \
# 0     (Chains: CWE-20->CWE-125) Desc: "out of bounds...
# 1     (Chains: CWE-20->CWE-125) Desc: "out of bounds...
# 2     (Chains: CWE-20->CWE-125) Desc: "out of bounds...
# 3     (Chains: CWE-20->CWE-125) Desc: "out of bounds...
# 4     (Chains: CWE-190->CWE-125) Desc: "out of bound...
# ...                                                 ...
# 9707  "due to an improper input validation". ref men...
# 9708  "Improper Input Validation" in desc. NVD vendo...
# 9709  "improper input handling" and NVD Reference ma...
# 9710  desc: "CWE-20: Improper Input Validation" and ...
# 9711  desc: "CWE-20: Improper Input Validation" and ...
#
#                                             Description
# 0     In alac decoder, there is a possible out of bo...
# 1     In alac decoder, there is a possible out of bo...
# 2     In geniezone driver, there is a possible out o...
# 3     In geniezone driver, there is a possible out o...
# 4     In ccu driver, there is a possible out of boun...
# ...                                                 ...
# 9707  On various RAD-ISM-900-EN-* devices by PHOENIX...
# 9708  Improper Input Validation vulnerability in the...
# 9709  This vulnerability exists in Milesight Video M...
# 9710  A CWE-20: Improper Input Validation vulnerabil...
# 9711  A CWE-20: Improper Input Validation vulnerabil...
#
# [9712 rows x 4 columns]

# %% [markdown]
# ## Check for CVE Descriptions that are null
#
# * 1 row has null description - CVE-2021-44228 - this is because the CVE was rejected.
# * But we can still add the description from the CVE https://nvd.nist.gov/vuln/detail/CVE-2021-42248#VulnChangeHistorySection
# * "GJSON <= 1.9.2 allows attackers to cause a redos via crafted JSON input."

# %%
df['Description'].isnull().sum()
# Out:
# np.int64(1)

# %%
null_description_rows = df[df['Description'].isnull()]
null_description_rows
# Out:
#                  CVE   New CWE        Reasoning Description
# 2849  CVE-2021-42248  CWE-1333  "redos" in desc         NaN

# %%
df.loc[2849, 'Description'] = "GJSON <= 1.9.2 allows attackers to cause a redos via crafted JSON input."
df['Description'].isnull().sum()
# Out:
# np.int64(0)

# %%
# The regular expression r'CWE-\d+$' breaks down as follows:

# CWE-: Matches the literal string "CWE-"
# \d+: Matches one or more digits
# $: Ensures that the digits are at the end of the string

df = df[df['New CWE'].str.match(r'CWE-\d+$')]
df
# Out:
#                  CVE  New CWE  \
# 0      CVE-2021-0674   CWE-20
# 1      CVE-2021-0674  CWE-125
# 2      CVE-2021-0676   CWE-20
# 3      CVE-2021-0676  CWE-125
# 4      CVE-2021-0677  CWE-190
# ...              ...      ...
# 9707  CVE-2022-29897   CWE-20
# 9708  CVE-2022-29922   CWE-20
# 9709   CVE-2022-3001   CWE-20
# 9710  CVE-2022-30232   CWE-20
# 9711  CVE-2022-30233   CWE-20
#
#                                               Reasoning  \
# 0     (Chains: CWE-20->CWE-125) Desc: "out of bounds...
# 1     (Chains: CWE-20->CWE-125) Desc: "out of bounds...
# 2     (Chains: CWE-20->CWE-125) Desc: "out of bounds...
# 3     (Chains: CWE-20->CWE-125) Desc: "out of bounds...
# 4     (Chains: CWE-190->CWE-125) Desc: "out of bound...
# ...                                                 ...
# 9707  "due to an improper input validation". ref men...
# 9708  "Improper Input Validation" in desc. NVD vendo...
# 9709  "improper input handling" and NVD Reference ma...
# 9710  desc: "CWE-20: Improper Input Validation" and ...
# 9711  desc: "CWE-20: Improper Input Validation" and ...
#
#                                             Description
# 0     In alac decoder, there is a possible out of bo...
# 1     In alac decoder, there is a possible out of bo...
# 2     In geniezone driver, there is a possible out o...
# 3     In geniezone driver, there is a possible out o...
# 4     In ccu driver, there is a possible out of boun...
# ...                                                 ...
# 9707  On various RAD-ISM-900-EN-* devices by PHOENIX...
# 9708  Improper Input Validation vulnerability in the...
# 9709  This vulnerability exists in Milesight Video M...
# 9710  A CWE-20: Improper Input Validation vulnerabil...
# 9711  A CWE-20: Improper Input Validation vulnerabil...
#
# [8522 rows x 4 columns]

# %%
#df = df[df['New CWE'].str.startswith('CWE-')]
#df

# %%
# replace any sequence of whitespace characters (including newlines, tabs, and multiple spaces) with a single space.
df['Description'] = df['Description'].str.replace('\s+', ' ', regex=True)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_182794/1618951606.py:2: SyntaxWarning: invalid escape sequence '\s'
#   df['Description'] = df['Description'].str.replace('\s+', ' ', regex=True)
# /tmp/ipykernel_182794/1618951606.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Description'] = df['Description'].str.replace('\s+', ' ', regex=True)

# %% [markdown]
# ## Split the Reasoning column into Chains and Weakness_Description

# %%
def extract_info(reasoning):
    # Extract Chains
    chains_match = re.search(r'\(Chains: (.*?)\)', reasoning)
    chains = chains_match.group(1) if chains_match else ''

    # Extract Weakness Description
    desc_match = re.search(r'Desc: "(.*?)"', reasoning)
    if not desc_match:
        desc_match = re.search(r'"(.*?)"', reasoning)
    weakness_description = desc_match.group(1) if desc_match else ''

    return pd.Series({'Chains': chains, 'Weakness_Description': weakness_description})

# %%
# Apply the extraction function to the 'Reasoning' column
new_columns = df['Reasoning'].apply(extract_info)

# Add the new columns to the DataFrame
df = pd.concat([df, new_columns], axis=1)

df
# Out:
#                  CVE  New CWE  \
# 0      CVE-2021-0674   CWE-20
# 1      CVE-2021-0674  CWE-125
# 2      CVE-2021-0676   CWE-20
# 3      CVE-2021-0676  CWE-125
# 4      CVE-2021-0677  CWE-190
# ...              ...      ...
# 9707  CVE-2022-29897   CWE-20
# 9708  CVE-2022-29922   CWE-20
# 9709   CVE-2022-3001   CWE-20
# 9710  CVE-2022-30232   CWE-20
# 9711  CVE-2022-30233   CWE-20
#
#                                               Reasoning  \
# 0     (Chains: CWE-20->CWE-125) Desc: "out of bounds...
# 1     (Chains: CWE-20->CWE-125) Desc: "out of bounds...
# 2     (Chains: CWE-20->CWE-125) Desc: "out of bounds...
# 3     (Chains: CWE-20->CWE-125) Desc: "out of bounds...
# 4     (Chains: CWE-190->CWE-125) Desc: "out of bound...
# ...                                                 ...
# 9707  "due to an improper input validation". ref men...
# 9708  "Improper Input Validation" in desc. NVD vendo...
# 9709  "improper input handling" and NVD Reference ma...
# 9710  desc: "CWE-20: Improper Input Validation" and ...
# 9711  desc: "CWE-20: Improper Input Validation" and ...
#
#                                             Description            Chains  \
# 0     In alac decoder, there is a possible out of bo...   CWE-20->CWE-125
# 1     In alac decoder, there is a possible out of bo...   CWE-20->CWE-125
# 2     In geniezone driver, there is a possible out o...   CWE-20->CWE-125
# 3     In geniezone driver, there is a possible out o...   CWE-20->CWE-125
# 4     In ccu driver, there is a possible out of boun...  CWE-190->CWE-125
# ...                                                 ...               ...
# 9707  On various RAD-ISM-900-EN-* devices by PHOENIX...
# 9708  Improper Input Validation vulnerability in the...
# 9709  This vulnerability exists in Milesight Video M...
# 9710  A CWE-20: Improper Input Validation vulnerabil...
# 9711  A CWE-20: Improper Input Validation vulnerabil...
#
#                                    Weakness_Description
# 0     out of bounds read due to an incorrect bounds ...
# 1     out of bounds read due to an incorrect bounds ...
# 2     out of bounds read due to an incorrect bounds ...
# 3     out of bounds read due to an incorrect bounds ...
# 4         out of bounds read due to an integer overflow
# ...                                                 ...
# 9707                due to an improper input validation
# 9708                          Improper Input Validation
# 9709                            improper input handling
# 9710                  CWE-20: Improper Input Validation
# 9711                  CWE-20: Improper Input Validation
#
# [8522 rows x 6 columns]

# %%
df.to_csv("./data_out/top25-mitre-mapping-analysis-2023-public_with_cve_descriptions_with reasoning.csv", index=False, quoting=csv.QUOTE_ALL, escapechar='\\')

# %%
df.drop('Reasoning', axis=1, inplace=True)
df.rename(columns={'New CWE': 'CWE'}, inplace=True)
df
# Out:
#                  CVE      CWE  \
# 0      CVE-2021-0674   CWE-20
# 1      CVE-2021-0674  CWE-125
# 2      CVE-2021-0676   CWE-20
# 3      CVE-2021-0676  CWE-125
# 4      CVE-2021-0677  CWE-190
# ...              ...      ...
# 9707  CVE-2022-29897   CWE-20
# 9708  CVE-2022-29922   CWE-20
# 9709   CVE-2022-3001   CWE-20
# 9710  CVE-2022-30232   CWE-20
# 9711  CVE-2022-30233   CWE-20
#
#                                             Description            Chains  \
# 0     In alac decoder, there is a possible out of bo...   CWE-20->CWE-125
# 1     In alac decoder, there is a possible out of bo...   CWE-20->CWE-125
# 2     In geniezone driver, there is a possible out o...   CWE-20->CWE-125
# 3     In geniezone driver, there is a possible out o...   CWE-20->CWE-125
# 4     In ccu driver, there is a possible out of boun...  CWE-190->CWE-125
# ...                                                 ...               ...
# 9707  On various RAD-ISM-900-EN-* devices by PHOENIX...
# 9708  Improper Input Validation vulnerability in the...
# 9709  This vulnerability exists in Milesight Video M...
# 9710  A CWE-20: Improper Input Validation vulnerabil...
# 9711  A CWE-20: Improper Input Validation vulnerabil...
#
#                                    Weakness_Description
# 0     out of bounds read due to an incorrect bounds ...
# 1     out of bounds read due to an incorrect bounds ...
# 2     out of bounds read due to an incorrect bounds ...
# 3     out of bounds read due to an incorrect bounds ...
# 4         out of bounds read due to an integer overflow
# ...                                                 ...
# 9707                due to an improper input validation
# 9708                          Improper Input Validation
# 9709                            improper input handling
# 9710                  CWE-20: Improper Input Validation
# 9711                  CWE-20: Improper Input Validation
#
# [8522 rows x 5 columns]

# %%
df.drop(columns=['CWE'], inplace=True)
df = df.drop_duplicates()
#df = df.reset_index(drop=True)
df.to_csv("./data_out/top25-mitre-mapping-analysis-2023-public_with_cve_descriptions.csv", index=False, quoting=csv.QUOTE_ALL, escapechar='\\')

# %%
#df[:100].to_csv("./data_out/100_top25-mitre-mapping-analysis-2023-public_with_cve_descriptions.csv", index=False, quoting=csv.QUOTE_ALL, escapechar='\\')

# %%
df.CVE.value_counts()
# Out:
# CVE
# CVE-2022-30233    1
# CVE-2022-29198    1
# CVE-2022-29197    1
# CVE-2022-29196    1
# CVE-2022-29195    1
#                  ..
# CVE-2021-0895     1
# CVE-2021-0679     1
# CVE-2021-0678     1
# CVE-2021-0677     1
# CVE-2021-0676     1
# Name: count, Length: 6945, dtype: int64

# %%
df.Chains.value_counts()
# Out:
# Chains
#                                                      6024
# CWE-1287->CWE-617                                     148
# CWE-20->CWE-787                                       148
# CWE-362->CWE-416                                       86
# CWE-352->CWE-79, CWE-116->CWE-79, CWE-138->CWE-79      72
#                                                      ...
# CWE-20->CWE-369                                         2
# CWE-138->CWE-943                                        2
# CWE-790->CWE-943                                        2
# CWE-20->CWE-444                                         2
# CWE-170->CWE-125                                        2
# Name: count, Length: 437, dtype: int64

# %%
df.Weakness_Description.isnull().value_counts()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9707    False
# 9708    False
# 9709    False
# 9710    False
# 9711    False
# Name: Weakness_Description, Length: 8522, dtype: bool
